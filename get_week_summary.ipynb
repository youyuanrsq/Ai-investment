# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.7a17-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 620 kB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: matplotlib in /home/zhubo/.local/lib/python3.8/site-packages (from mplfinance) (3.4.2)
# Requirement already satisfied, skipping upgrade: pandas in /home/zhubo/.local/lib/python3.8/site-packages (from mplfinance) (1.2.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (2.4.7)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (8.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /home/zhubo/.local/lib/python3.8/site-packages (from matplotlib->mplfinance) (1.20.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /home/zhubo/.local/lib/python3.8/site-packages (from pandas->mplfinance) (2021.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.14.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.7a17

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import glob
import json
import mplfinance as mpf

# %%
def convert_sec_to_min(date):
    split_date = date.split(':')
    min_date = split_date[0]+':'+split_date[1]+':00'
    return min_date


def get_data(stock_name='AAPL', start='2015-01-01', end='2015-12-25',interval= '1m'):
    stock_names = stock_name.split()
    df = yf.download(stock_name, start=start, end=end, group_by='ticker', interval = interval)
    return df
def get_trade_signal(trading_date, price,direction):
    import numpy as np
    signal   = []
    previous = -1.0
    factor = 0.99 if direction == 'buy' else 1.01
    new_trade = []
    for i in trading_date:
        continue_flag = 1
        ind = 0 
      #  import pdb;pdb.set_trace()
        while continue_flag:
            try:
               print(price.loc[i])
               new_trade.append(i)
               continue_flag = 0
            except Exception as e:
               print('can not find the date in k line',e)
               ind +=1
               i = str(datetime.datetime.strptime(i,"%Y-%m-%d %H:%M:%S") + datetime.timedelta(minutes=1))
              
            if ind > 10:
                continue_flag = 0
    if len(new_trade) == 0:
       for i in trading_date:
        continue_flag = 1
        ind = 0 
      #  import pdb;pdb.set_trace()
        while continue_flag:
            try:
               print(price.loc[i])
               new_trade.append(i)
               continue_flag = 0
            except Exception as e:
               print('can not find the date in k line',e)
               ind +=1
               i = str(datetime.datetime.strptime(i,"%Y-%m-%d %H:%M:%S") - datetime.timedelta(minutes=1))
              
            if ind > 10:
                continue_flag = 0
        

    for date,value in price.iteritems():
        tem_date = str(date).split('-04')[0]
        if  tem_date in new_trade:
            print(date)
            signal.append(price[date]*factor)

        else:
            signal.append(np.nan)
        previous = value
    return signal

def get_stock_price_info(ticker,period = '1y',interval = '1d',):
   data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = ticker,

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = period,

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = interval,

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all k line automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = False,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
   return data

# %%
def draw_trading_log(data, symbol, end):
    trading_log = {}
    for i in range(5):
        try:
            start = str( end - datetime.timedelta(days=i))
            with open(log_save_path+ start+'/'+symbol+'.json') as f:       
                 data = json.load(f)
            trading_log.update(data)
        except Exception as e:
            print(e)

    buy_date = [convert_sec_to_min(i) for i in trading_log.keys() if trading_log[i]['Direction'] == 'buy']
    sell_date = [convert_sec_to_min(i) for i in trading_log.keys() if trading_log[i]['Direction'] == 'sell']        
    
    buy_signal = get_trade_signal(buy_date,[],week_data['Close'])
    sell_signal = get_trade_signal([],sell_date,week_data['Close'])

    apds = [ 
         mpf.make_addplot(buy_signal,type='scatter',markersize=200,marker='^'),
         mpf.make_addplot(sell_signal,type='scatter',markersize=200,marker='v'),
       ]
                 
                 
    mpf.plot(week_data,warn_too_much_data=2000,volume=True,addplot=apds)

# %%
def split_buy_sell_date(trading_log):
    sell_date = []
    buy_date = []
    for i in trading_log.keys():
        if i not in ['open', 'close', 'pre_open', 'pre_close'] :
           if trading_log[i]['Direction'] == 'buy' :
                buy_date.append(convert_sec_to_min(i))
           else:
                sell_date.append(convert_sec_to_min(i)) 
    return buy_date, sell_date

# %%
end = datetime.date.today() 

start = end -  datetime.timedelta(days=7)   
trading_stocks = [ 'AN', 'AVLR', 'CHGG', 'CMG', 'CPA', 'CRWD', 'DE', 'ELAN', 'EVR', 'FIVN', 'GO', 'HD', 'LPLA', 'PAG', 'PD', 'QRTEA', 'RNG', 'RYN', 'TTC', 'WY']
for symbol in list(trading_stocks):

    print(symbol)
    week_data = pd.read_csv('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol='+symbol+'&interval='+interval+'&slice='+time+'&apikey=H40LS6V3016EZSQ6',index_col=False)
    week_data = week_data[::-1].reset_index()
    week_data.index = pd.to_datetime(week_data.time)
    week_data  = week_data[start : ]
    #week_data = get_data(stock_name=symbol, start=start, end=end)
    trading_log = {}
    mpf.plot(week_data,warn_too_much_data=3000,volume=True, title = symbol,
                  savefig=dict(fname=symbol+'.jpg',dpi=100,pad_inches=0.25))
    print('save the image', symbol )

import glob
import img2pdf
with open(str(end)+"_stock_pool.pdf","wb") as f:

         f.write(img2pdf.convert([i+".jpg" for i in trading_stocks]))
# Out:
# AN
# save the image AN
# AVLR
# save the image AVLR
# CHGG
# save the image CHGG
# CMG
# save the image CMG
# CPA
# save the image CPA
# CRWD
# save the image CRWD
# DE
# save the image DE
# ELAN
# save the image ELAN
# EVR
# save the image EVR
# FIVN
# save the image FIVN
# GO
# save the image GO
# HD
# save the image HD
# LPLA
# save the image LPLA
# PAG
# save the image PAG
# PD
# save the image PD
# QRTEA
# save the image QRTEA
# RNG
# save the image RNG
# RYN
# save the image RYN
# TTC
# save the image TTC
# WY
# save the image WY

# %%
end = datetime.date.today() 

log_save_path='/mnt/c/Users/zhubo/Documents/trading_data/'
trading_stocks = []
for i in range(7):
    start = str( end - datetime.timedelta(days=i))
    trading_stocks += glob.glob(log_save_path+ start+'/*.json')
trading_stocks = set([ i.split('/')[-1].split('.')[0] for i in trading_stocks])
start = end -  datetime.timedelta(days=7)   

for symbol in list(trading_stocks):

    print(symbol)
    week_data = pd.read_csv('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol='+symbol+'&interval='+interval+'&slice='+time+'&apikey=H40LS6V3016EZSQ6',index_col=False)
    week_data = week_data[::-1].reset_index()
    week_data.index = pd.to_datetime(week_data.time)
    week_data  = week_data[start : ]
   # week_data = get_data(stock_name=symbol, start=start, end=end)
    trading_log = {}
    for i in range(7):
        try:
            start = str( end - datetime.timedelta(days=i))
            print(start)
            with open(log_save_path+ start+'/'+symbol+'.json') as f:       
                 data = json.load(f)
            trading_log.update(data)
        except Exception as e:
            pass
    print('trading log', trading_log)
    
    buy_date, sell_date = split_buy_sell_date(trading_log)     
    
    buy_signal = get_trade_signal(buy_date,week_data['close'], 'buy')
    sell_signal = get_trade_signal(sell_date,week_data['close'], 'sell')

    apds = []
    if sum(~np.isnan(buy_signal)) >0:
         apds.append(mpf.make_addplot(buy_signal,type='scatter',markersize=200,marker='^'))
    if sum(~np.isnan(sell_signal)) >0:
         apds.append(mpf.make_addplot(sell_signal,type='scatter',markersize=200,marker='v'))
    if len(apds) > 0:

       mpf.plot(week_data,warn_too_much_data=2000,volume=True,addplot=apds, title = symbol,
                  savefig=dict(fname=symbol+'.jpg',dpi=100,pad_inches=0.25))
       print('save the image')
    else:
       mpf.plot(week_data,warn_too_much_data=2000,volume=True, title = symbol,
                  savefig=dict(fname=symbol+'.jpg',dpi=100,pad_inches=0.25))
       print('save the image', symbol )

import glob
import img2pdf
with open(str(start)+'_'+str(end)+"_trading_log.pdf","wb") as f:
    f.write(img2pdf.convert(glob.glob("*.jpg")))
# Out:
# FLL
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-11 11:17:00': {'Symbol': 'FLL', 'Price': 9.483426706136083, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-07 12:22:00': {'Symbol': 'FLL', 'Price': 10.98, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 9.483151791473807, 'stop_earning_range': 11.866848208526193}}
# 10.96
# 2021-06-07 12:22:00
# 9.55
# 2021-06-11 11:17:00
# save the image
# PD
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 15:45:00': {'Symbol': 'PD', 'Price': 38.64, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 32.23818724358395, 'stop_earning_range': 41.72181275641605}, '2021-06-08 13:45:00': {'Symbol': 'PD', 'Price': 38.64, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 32.23818724358395, 'stop_earning_range': 41.72181275641605}, '2021-06-08 15:54:00': {'Symbol': 'PD', 'Price': 38.86, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:56:00': {'Symbol': 'PD', 'Price': 38.83, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}}
# 39.075
# 38.575
# 2021-06-08 13:45:00
# 2021-06-08 15:45:00
# 38.93
# 38.805
# 2021-06-08 15:54:00
# 2021-06-08 15:56:00
# save the image
# GO
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 15:59:00': {'Symbol': 'GO', 'Price': 33.92, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 32.50772846035796, 'stop_earning_range': 34.87227153964204}, '2021-06-10 12:21:00': {'Symbol': 'GO', 'Price': 33.99, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 32.863817408441335, 'stop_earning_range': 34.86618259155867}, '2021-06-03 15:54:00': {'Symbol': 'GO', 'Price': 34.34, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 33.12948550973398, 'stop_earning_range': 35.37051449026602}, '2021-06-03 15:59:00': {'Symbol': 'GO', 'Price': 34.34, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 33.25229527610753, 'stop_earning_range': 35.24770472389247}, '2021-06-08 15:32:00': {'Symbol': 'GO', 'Price': 33.92, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 32.50772846035796, 'stop_earning_range': 34.87227153964204}}
# 33.99
# 33.95
# can not find the date in k line '2021-06-03 15:54:00'
# can not find the date in k line '2021-06-03 15:55:00'
# can not find the date in k line '2021-06-03 15:56:00'
# can not find the date in k line '2021-06-03 15:57:00'
# can not find the date in k line '2021-06-03 15:58:00'
# can not find the date in k line '2021-06-03 15:59:00'
# can not find the date in k line '2021-06-03 16:00:00'
# can not find the date in k line '2021-06-03 16:01:00'
# can not find the date in k line '2021-06-03 16:02:00'
# can not find the date in k line '2021-06-03 16:03:00'
# can not find the date in k line '2021-06-03 16:04:00'
# can not find the date in k line '2021-06-03 15:59:00'
# can not find the date in k line '2021-06-03 16:00:00'
 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 588.1435746409979, 'stop_earning_range': 643.4764253590021}, '2021-06-07 15:59:00': {'Symbol': 'RH', 'Price': 618.45, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 589.5266761870878, 'stop_earning_range': 642.0933238129122}}
# 696.12
# can not find the date in k line '2021-06-07 12:08:00'
# 624.51
# 624.83
# 2021-06-07 12:09:00
# 2021-06-07 15:59:00
# 2021-06-10 09:37:00
# save the image
# FIVN
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-09 12:39:00': {'Symbol': 'FIVN', 'Price': 160.75, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 151.292977787091, 'stop_earning_range': 168.777022212909}, '2021-06-09 11:55:00': {'Symbol': 'FIVN', 'Price': 160.75, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 151.292977787091, 'stop_earning_range': 168.777022212909}}
# 164.415
# 162.77
# 2021-06-09 11:55:00
# 2021-06-09 12:39:00
# save the image
# MVIS
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-10 09:46:00': {'Symbol': 'MVIS', 'Price': 23.03, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 18.434270037373363, 'stop_earning_range': 25.76592996262664}, '2021-06-04 12:54:00': {'Symbol': 'MVIS', 'Price': 19.05, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 15.721865677472648, 'stop_earning_range': 21.30813432252735}, '2021-06-04 15:59:00': {'Symbol': 'MVIS', 'Price': 19.05, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 15.21954781423331, 'stop_earning_range': 21.810452185766692}}
# 22.99
# can not find the date in k line '2021-06-04 12:54:00'
# can not find the date in k line '2021-06-04 12:55:00'
# can not find the date in k line '2021-06-04 12:56:00'
# can not find the date in k line '2021-06-04 12:57:00'
# can not find the date in k line '2021-06-04 12:58:00'
# can not find the date in k line '2021-06-04 12:59:00'
# can not find the date in k line '2021-06-04 13:00:00'
# can not find the date in k line '2021-06-04 13:01:00'
# can not find the date in k line '2021-06-04 13:02:00'
# can not find the date in k line '2021-06-04 13:03:00'
# can not find the date in k line '2021-06-04 13:04:00'
# can not find the date in k line '2021-06-04 15:59:00'
# can not find the date in k line '2021-06-04 16:00:00'
# can not find the date in k line '2021-06-04 16:01:00'
# can not find the date in k line '2021-06-04 16:02:00'
# can not find the date in k line '2021-06-04 16:03:00'
# can not find the date in k line '2021-06-04 16:04:00'
# can not find the date in k line '2021-06-04 16:05:00'
# can not find the date in k line '2021-06-04 16:06:00'
# can not find the date in k line '2021-06-04 16:07:00'
# can not find the date in k line '2021-06-04 16:08:00'
# can not find the date in k line '2021-06-04 16:09:00'
# 2021-06-10 09:46:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# QRTEA
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 11:54:00': {'Symbol': 'QRTEA', 'Price': 13.58, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 12.577602134401518, 'stop_earning_range': 14.232397865598482}, '2021-06-08 11:48:00': {'Symbol': 'QRTEA', 'Price': 13.58, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 12.577602134401518, 'stop_earning_range': 14.232397865598482}, '2021-06-08 15:58:00': {'Symbol': 'QRTEA', 'Price': 13.75, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:59:00': {'Symbol': 'QRTEA', 'Price': 13.58, 'Direction': 'buy', 'Size': 1, 'Position': 0.0, 'stop_loss_range': 12.56296831928804, 'stop_earning_range': 14.247031680711961}}
# 13.75
# 13.74
# 13.75
# 2021-06-08 11:48:00
# 2021-06-08 11:54:00
# 2021-06-08 15:59:00
# 13.7367
# 2021-06-08 15:58:00
# save the image
# CPSH
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-09 13:35:00': {'Symbol': 'EMAN', 'Price': 3.57, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 2.993191800542638, 'stop_earning_range': 3.976808199457362}, '2021-06-04 12:12:00': {'Symbol': 'EMAN', 'Price': 3.6, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 2.966182071575411, 'stop_earning_range': 4.043817928424589}}
# 3.55
# can not find the date in k line '2021-06-04 12:12:00'
# can not find the date in k line '2021-06-04 12:13:00'
# can not find the date in k line '2021-06-04 12:14:00'
# can not find the date in k line '2021-06-04 12:15:00'
# can not find the date in k line '2021-06-04 12:16:00'
# can not find the date in k line '2021-06-04 12:17:00'
# can not find the date in k line '2021-06-04 12:18:00'
# can not find the date in k line '2021-06-04 12:19:00'
# can not find the date in k line '2021-06-04 12:20:00'
# can not find the date in k line '2021-06-04 12:21:00'
# can not find the date in k line '2021-06-04 12:22:00'
# 2021-06-09 13:35:00
# save the image
# CHGG
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 15:59:00': {'Symbol': 'CHGG', 'Price': 74.43, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 69.57252142788623, 'stop_earning_range': 77.35747857211378}, '2021-06-08 10:59:00': {'Symbol': 'CHGG', 'Price': 74.43, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 69.57252142788623, 'stop_earning_range': 77.35747857211378}, '2021-06-08 15:54:00': {'Symbol': 'CHGG', 'Price': 75.36, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:57:00': {'Symbol': 'CHGG', 'Price': 75.44, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}}
# 75.46
# 74.755
# 2021-06-08 10:59:00
# 2021-06-08 15:59:00
# 75.41
# 75.38
# 2021-06-08 15:54:00
# 2021-06-08 15:57:00
# save the image
# RNG
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 14:12:00': {'Symbol': 'RNG', 'Price': 250.0, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 235.2334828154519, 'stop_earning_range': 261.7665171845481}, '2021-06-08 12:38:00': {'Symbol': 'RNG', 'Price': 250.0, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 235.2334828154519, 'stop_earning_range': 261.7665171845481}, '2021-06-08 15:54:00': {'Symbol': 'RNG', 'Price': 253.77, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:56:00': {'Symbol': 'RNG', 'Price': 253.54, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:58:00': {'Symbol': 'RNG', 'Price': 253.85, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:59:00': {'Symbol': 'RNG', 'Price': 250.0, 'Direction': 'buy', 'Size': 1, 'Position': 0.0, 'stop_loss_range': 235.002400365945, 'stop_earning_range': 261.997599634055}}
# 255.33
# 253.1
# 253.85
# 2021-06-08 12:38:00
# 2021-06-08 14:12:00
# 2021-06-08 15:59:00
# 254.155
# 253.43
# 253.75
# 2021-06-08 15:54:00
# 2021-06-08 15:56:00
# 2021-06-08 15:58:00
# save the image
# EPIX
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 10:49:00': {'Symbol': 'EPIX', 'Price': 31.54, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 28.69309420302973, 'stop_earning_range': 34.06690579697027}, '2021-06-09 14:21:00': {'Symbol': 'EPIX', 'Price': 28.922692327925976, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-07 11:14:00': {'Symbol': 'EPIX', 'Price': 32.3, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 27.96356299839665, 'stop_earning_range': 34.86643700160335}}
# can not find the date in k line '2021-06-08 10:49:00'
# 31.72
# 32.19
# 2021-06-07 11:14:00
# 2021-06-08 10:50:00
# 29.02
# 2021-06-09 14:21:00
# save the image
# MKTY
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 10:01:00': {'Symbol': 'MKTY', 'Price': 7.91, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 7.231758786816752, 'stop_earning_range': 8.428241213183249}, '2021-06-03 15:13:00': {'Symbol': 'MKTY', 'Price': 8.0, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range':
 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 119.37301755359812, 'stop_earning_range': 133.95698244640187}, '2021-06-07 15:59:00': {'Symbol': 'AVLR', 'Price': 128.5, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 118.5995057394002, 'stop_earning_range': 134.73049426059978}, '2021-06-07 11:03:00': {'Symbol': 'AVLR', 'Price': 128.5, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 119.37301755359812, 'stop_earning_range': 133.95698244640187}}
# 129.995
# 130.89
# can not find the date in k line '2021-06-07 11:03:00'
# 128.57
# 2021-06-07 11:04:00
# 2021-06-07 13:06:00
# 2021-06-07 15:59:00
# save the image
# WY
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-09 15:00:00': {'Symbol': 'WY', 'Price': 36.02, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 34.54077839044227, 'stop_earning_range': 37.04922160955773}, '2021-06-09 14:32:00': {'Symbol': 'WY', 'Price': 36.02, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 34.54077839044227, 'stop_earning_range': 37.04922160955773}}
# 36.235
# 36.205
# 2021-06-09 14:32:00
# 2021-06-09 15:00:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# HD
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 15:02:00': {'Symbol': 'HD', 'Price': 312.11, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 304.3902957427325, 'stop_earning_range': 317.6997042572675}}
# 312.0601
# 2021-06-08 15:02:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# TTC
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 12:57:00': {'Symbol': 'TTC', 'Price': 106.43, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 102.23943206330974, 'stop_earning_range': 109.12056793669028}, '2021-06-08 12:22:00': {'Symbol': 'TTC', 'Price': 106.43, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 102.23943206330974, 'stop_earning_range': 109.12056793669028}, '2021-06-08 15:54:00': {'Symbol': 'TTC', 'Price': 106.66, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-08 15:59:00': {'Symbol': 'TTC', 'Price': 106.77, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}}
# 106.645
# 106.41
# 2021-06-08 12:22:00
# 2021-06-08 12:57:00
# 106.79
# 106.7
# 2021-06-08 15:54:00
# 2021-06-08 15:59:00
# save the image
# UCTT
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-07 15:14:00': {'Symbol': 'UCTT', 'Price': 55.96, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 53.673743483599864, 'stop_earning_range': 58.60625651640014}}
# 57.66
# 2021-06-07 15:14:00
# save the image
# EVR
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-08 15:22:00': {'Symbol': 'EVR', 'Price': 142.11, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 137.5595011324762, 'stop_earning_range': 146.0104988675238}, '2021-06-07 13:24:00': {'Symbol': 'EVR', 'Price': 142.2, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 137.14389198863935, 'stop_earning_range': 146.29610801136064}, '2021-06-08 15:23:00': {'Symbol': 'EVR', 'Price': 142.11, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 137.5595011324762, 'stop_earning_range': 146.0104988675238}}
# can not find the date in k line '2021-06-08 15:22:00'
# 142.105
# 142.14
# 142.105
# 2021-06-07 13:24:00
# 2021-06-08 15:23:00
# save the image
# JYNT
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-03 14:27:00': {'Symbol': 'JYNT', 'Price': 71.99, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 67.2867196288649, 'stop_earning_range': 75.9632803711351}, '2021-06-04 15:59:00': {'Symbol': 'JYNT', 'Price': 71.6, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 66.2714551915877, 'stop_earning_range': 75.31854480841228}}
# can not find the date in k line '2021-06-03 14:27:00'
# can not find the date in k line '2021-06-03 14:28:00'
# can not find the date in k line '2021-06-03 14:29:00'
# can not find the date in k line '2021-06-03 14:30:00'
# can not find the date in k line '2021-06-03 14:31:00'
# can not find the date in k line '2021-06-03 14:32:00'
# can not find the date in k line '2021-06-03 14:33:00'
# can not find the date in k line '2021-06-03 14:34:00'
# can not find the date in k line '2021-06-03 14:35:00'
# can not find the date in k line '2021-06-03 14:36:00'
# can not find the date in k line '2021-06-03 14:37:00'
# can not find the date in k line '2021-06-04 15:59:00'
# can not find the date in k line '2021-06-04 16:00:00'
# can not find the date in k line '2021-06-04 16:01:00'
# can not find the date in k line '2021-06-04 16:02:00'
# can not find the date in k line '2021-06-04 16:03:00'
# can not find the date in k line '2021-06-04 16:04:00'
# can not find the date in k line '2021-06-04 16:05:00'
# can not find the date in k line '2021-06-04 16:06:00'
# can not find the date in k line '2021-06-04 16:07:00'
# can not find the date in k line '2021-06-04 16:08:00'
# can not find the date in k line '2021-06-04 16:09:00'
# can not find the date in k line '2021-06-03 14:27:00'
# can not find the date in k line '2021-06-03 14:26:00'
# can not find the date in k line '2021-06-03 14:25:00'
# can not find the date in k line '2021-06-03 14:24:00'
# can not find the date in k line '2021-06-03 14:23:00'
# can not find the date in k line '2021-06-03 14:22:00'
# can not find the date in k line '2021-06-03 14:21:00'
# can not find the date in k line '2021-06-03 14:20:00'
# can not find the date in k line '2021-06-03 14:19:00'
# can not find the date in k line '2021-06-03 14:18:00'
# can not find the date in k line '2021-06-03 14:17:00'
# can not find the date in k line '2021-06-04 15:59:00'
# can not find the date in k line '2021-06-04 15:58:00'
# can not find the date in k line '2021-06-04 15:57:00'
# can not find the date in k line '2021-06-04 15:56:00'
# can not find the date in k line '2021-06-04 15:55:00'
# can not find the date in k line '2021-06-04 15:54:00'
# can not find the date in k line '2021-06-04 15:53:00'
# can not find the date in k line '2021-06-04 15:52:00'
# can not find the date in k line '2021-06-04 15:51:00'
# can not find the date in k line '2021-06-04 15:50:00'
# can not find the date in k line '2021-06-04 15:49:00'
# save the image JYNT
# CRWD
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-10 10:45:00': {'Symbol': 'CRWD', 'Price': 217.31, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 203.9861901047408, 'stop_earning_range': 227.21380989525917}, '2021-06-10 10:07:00': {'Symbol': 'CRWD', 'Price': 217.31, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 203.9861901047408, 'stop_earning_range': 227.21380989525917}, '2021-06-10 15:54:00': {'Symbol': 'CRWD', 'Price': 228.21, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-10 15:57:00': {'Symbol': 'CRWD', 'Price': 228.16, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-10 15:59:00': {'Symbol': 'CRWD', 'Price': 228.69, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}}
# 218.695
# 221.6386
# 2021-06-10 10:07:00
# 2021-06-10 10:45:00
# 228.575
# 227.945
# 228.38
# 2021-06-10 15:54:00
# 2021-06-10 15:57:00
# 2021-06-10 15:59:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# NIO
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-07 11:12:00': {'Symbol': 'NIO', 'Price': 40.9, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 39.10174442278927, 'stop_earning_range': 43.18825557721073}, '2021-06-07 15:59:00': {'Symbol': 'NIO', 'Price': 40.9, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 38.99070601944456, 'stop_earning_range': 43.29929398055544}}
# 43.172
# 43.6363
# 2021-06-07 11:12:00
# 2021-06-07 15:59:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# LOVE
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-09 11:43:00': {'Symbol': 'LOVE', 'Price': 83.86, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 75.53519040882765, 'stop_earning_range': 89.68480959117235}, '2021-06-10 15:59:00': {'Symbol': 'LOVE', 'Price': 85.52, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 75.53892794217876, 'stop_earning_range': 91.74107205782124}, '2021-06-07 13:03:00': {'Symbol': 'LOVE', 'Price': 85.01, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 77.08991516654261, 'stop_earning_range': 91.0700848334574}, '2021-06-03 10:55:00': {'Symbol': 'LOVE', 'Price': 85.67, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 80.46426732232388, 'stop_earning_range': 90.70573267767612}}
# 86.81
# 87.49
# 85.82
# can not find the date in k line '2021-06-03 10:55:00'
# can not find the date in k line '2021-06-03 10:56:00'
# can not find the date in k line '2021-06-03 10:57:00'
# can not find the date in k line '2021-06-03 10:58:00'
# can not find the date in k line '2021-06-03 10:59:00'
# can not find the date in k line '2021-06-03 11:00:00'
# can not find the date in k line '2021-06-03 11:01:00'
# can not find the date in k line '2021-06-03 11:02:00'
# can not find the date in k line '2021-06-03 11:03:00'
# can not find the date in k line '2021-06-03 11:04:00'
# can not find the date in k line '2021-06-03 11:05:00'
# 2021-06-07 13:03:00
# 2021-06-09 11:43:00
# 2021-06-10 15:59:00
# save the image
# DXYN
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-10 12:14:00': {'Symbol': 'DXYN', 'Price': 2.4896817811681617, 'Direction': 'sell', 'Size': 1.0, 'Position': 0}, '2021-06-07 10:33:00': {'Symbol': 'DXYN', 'Price': 2.75, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 2.5155291876094252, 'stop_earning_range': 2.928170812390575}}
# can not find the date in k line '2021-06-07 10:33:00'
# 2.77
# 2021-06-07 10:34:00
# 2.54
# 2021-06-10 12:14:00
# save the image
# MP
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-07 15:45:00': {'Symbol': 'MP', 'Price': 31.36, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 29.36384942585182, 'stop_earning_range': 33.54615057414818}, '2021-06-04 13:43:00': {'Symbol': 'MP', 'Price': 31.71, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 28.775830186332538, 'stop_earning_range': 33.86416981366746}, '2021-06-07 15:59:00': {'Symbol': 'MP', 'Price': 31.36, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 29.308897264276773, 'stop_earning_range': 33.601102735723224}}
# 33.06
# can not find the date in k line '2021-06-04 13:43:00'
# can not find the date in k line '2021-06-04 13:44:00'
# can not find the date in k line '2021-06-04 13:45:00'
# can not find the date in k line '2021-06-04 13:46:00'
# can not find the date in k line '2021-06-04 13:47:00'
# can not find the date in k line '2021-06-04 13:48:00'
# can not find the date in k line '2021-06-04 13:49:00'
# can not find the date in k line '2021-06-04 13:50:00'
# can not find the date in k line '2021-06-04 13:51:00'
# can not find the date in k line '2021-06-04 13:52:00'
# can not find the date in k line '2021-06-04 13:53:00'
# 33.005
# 2021-06-07 15:45:00
# 2021-06-07 15:59:00
# /home/zhubo/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
# save the image
# ANVS
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# trading log {'2021-06-03 11:03:00': {'Symbol': 'ANVS', 'Price': 57.26, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range': 42.01562262981844, 'stop_earning_range': 70.04437737018155}, '2021-06-03 15:59:00': {'Symbol': 'ANVS', 'Price': 57.26, 'Direction': 'buy', 'Size': 1, 'Position': 0, 'stop_loss_range':